# %%
import wave
import numpy as np
import scipy.signal
import scipy.fft
import matplotlib.pyplot as plt
import soundfile as sf
from numpy import sin, cos, pi
import math
from copy import deepcopy

# %%
def f2keynum(fundamental_frequency):
    return round(12*math.log2(fundamental_frequency/440)+49)

def keynum2f(n):
    return 2**((n-49)/12)*440

def app(basic_array,given_array):
    m=0
    d=10**10
    for i in given_array :
        for j in basic_array :
            n=abs(j-i)
            if n<d:
                d=n
                given_array[m]=j
        m+=1
        d=10**10
    return given_array


def merge(array):
    h = 4
    result=array.copy()
    for i in range(10000):
        for j in range(len(result)):
            if h*i<result[j] and result[j]<h*(i+1):
                if abs(result[j]-h*i)<abs(result[j]-h*(i+1)):
                    del result[j]
                    result.insert(j,h*i)
                elif abs(result[j]-h*i)>abs(result[j]-h*(i+1)):
                    del result[j]
                    result.insert(j,h*(i + 1))
                    
    return result

def find_ind(L,k):
    for i in range(len(L)):
        if L[i][0]==k:
            return i

# notes = [('C3',28,[keynum2f(28),2*keynum2f(28),3*keynum2f(28),4*keynum2f(28)],[1.0,1.8748572028842412,0.3964491587480385,0.31215121741146373,0.16284341749618064,0.22523097807724257,0.14773314715517125,0.16390082081613377])
#        ,('C♯3',29,[keynum2f(29),2*keynum2f(29),3*keynum2f(29),4*keynum2f(29)],[1.0,1.641808167534372,0.362229104528428,0.3204856674017677,0.16009242547233515,0.21757203373160927,0.13014724989986423,0.1565141228439226])
#        ,('D3',30,[keynum2f(30),2*keynum2f(30),3*keynum2f(30),4*keynum2f(30)],[1.0,1.7624720432557146,0.38973935602968285,0.28663995734911973,0.1550463223252811,0.2094878675597662,0.1297044423409354,0.15633189557469926])
#        ,('D♯3',31,[keynum2f(31),2*keynum2f(31),3*keynum2f(31),4*keynum2f(31)],[1.0,0.684619288476615,0.05403268583420848,0.08247564203707748,0.09457374085631606,0.0684370921296874,0,0,0])
#        ,('E3',32,[keynum2f(32),2*keynum2f(32),3*keynum2f(32),4*keynum2f(32)],[1.0,0.644814919294843,0.0524292356278788,0.07378480741465424,0.09784674514032232,0.06818101225973808,0,0,0])
#        ,('F3',33,[keynum2f(33),2*keynum2f(33),3*keynum2f(33),4*keynum2f(33)],[1.0,0.6328411721378986,0.05272853181106699,0.07717785663706685,0.09266312228793924,0.067781748609678620,0,0])
#        ,('F♯3',34,[keynum2f(34),2*keynum2f(34),3*keynum2f(34),4*keynum2f(34)],[1.0,0.5581524414391876,0.044202567804296614,0.06312671806084452,0.08133730635315288,0.061706490568839340,0,0,0])
#        ,('G3',35,[keynum2f(35),2*keynum2f(35),3*keynum2f(35),4*keynum2f(35)],[1.0,0.5523796150087944,0.043284481581312206,0.06390858364936557,0.07939301094141947,0.05789010146996690,0,0,0])
#        ,('G♯3',36,[keynum2f(36),2*keynum2f(36),3*keynum2f(36),4*keynum2f(36)],[1.0,0.5942229569448632,0.04427436213918945,0.06654105453842608,0.07846406467501106,0.062889432614303560,0,0,0])
#        ,('A3',37,[keynum2f(37),2*keynum2f(37),3*keynum2f(37),4*keynum2f(37)],[1.0,0.7619580899495176,0.1045919068486756,0.13074141971372832,0.08461079636425631,0,0,0,0])
#        ,('A♯3',38,[keynum2f(38),2*keynum2f(38),3*keynum2f(38),4*keynum2f(38)],[1.0,0.8501318147396106,0.10653965806673261,0.14385563250865366,0.08478375144555607,0,0,0,0])
#        ,('B3',39,[keynum2f(39),2*keynum2f(39),3*keynum2f(39),4*keynum2f(39)],[1.0,0.8109901177231958,0.10439389881723116,0.13559165346145305,0.07923381544447580,0,0,0,0])
#        ,('C4',40,[keynum2f(40),2*keynum2f(40),3*keynum2f(40),4*keynum2f(40)],[1,0.45072320093010165, 0.07756067699435863, 0.06233478319526727,0,0,0,0])
#        ,('C♯4',41,[keynum2f(41),2*keynum2f(41),3*keynum2f(41),4*keynum2f(41)],[1,0.47975863251001355, 0.07705596758368384, 0.0590865572593957,0,0,0,0])
#        ,('D4',42,[keynum2f(42),2*keynum2f(42),3*keynum2f(42),4*keynum2f(42)],[1,0.4435033621543764, 0.07408747655496659, 0.05481959721494538,0,0,0,0])
#        ,('D♯4',43,[keynum2f(43),2*keynum2f(43),3*keynum2f(43),4*keynum2f(43)],[1,0.5572765658232384, 0.2805392604867455, 0.12346425135488595,0.11847019032008464,0,0,0,0])
#        ,('E4',44,[keynum2f(44),2*keynum2f(44),3*keynum2f(44),4*keynum2f(44)],[1,0.560838969957909, 0.2627388110929595, 0.1230569628956918,0.11195465659120205,0,0,0,0,0])
#        ,('F4',45,[keynum2f(45),2*keynum2f(45),3*keynum2f(45),4*keynum2f(45)],[1,0.5574742648780671,0.22399899087695116,0.11164689132907675,0.10444958701925663,0,0,0,0,0])
#        ,('F♯4',46,[keynum2f(46),2*keynum2f(46),3*keynum2f(46),4*keynum2f(46)],[1,0.5574742648780671,0.22399899087695116,0.11164689132907675,0.10444958701925663,0,0,0,0,0])
#        ,('G4',47,[keynum2f(47),2*keynum2f(47),3*keynum2f(47),4*keynum2f(47)],[1,0.07939819588721454, 0.03976683156570169,0,0,0,0,0])
#        ,('G♯4',48,[keynum2f(48),2*keynum2f(48),3*keynum2f(48),4*keynum2f(48)],[1,0.08156058683677495, 0.03336236688670703,0,0,0,0,0])
#        ,('A4',49,[keynum2f(49),2*keynum2f(49),3*keynum2f(49),4*keynum2f(49)],[1,0.07581809932930238, 0.03841706442666898,0,0,0,0,0])
#        ,('A♯4',50,[keynum2f(50),2*keynum2f(50),3*keynum2f(50),4*keynum2f(50)],[1,0.07529571131165992, 0.041580966713429625,0,0,0,0,0])
#        ,('B4',51,[keynum2f(51),2*keynum2f(51),3*keynum2f(51),4*keynum2f(51)],[1,0.08630751163794428, 0.039730627711715524,0,0,0,0,0])
#        ,('C5',52,[keynum2f(52),2*keynum2f(52),3*keynum2f(52),4*keynum2f(52)],[1.0, 0.251182570561093, 0.16467943558284057,0,0,0,0,0])
#        ,('C♯5',53,[keynum2f(53),2*keynum2f(53),3*keynum2f(53),4*keynum2f(53)],[1.0, 0.23748429609077507, 0.14979146857628187,0,0,0,0,0])
#        ,('D5',54,[keynum2f(54),2*keynum2f(54),3*keynum2f(54),4*keynum2f(54)],[1.0, 0.2473262521596234, 0.17682499106142524,0,0,0,0,0])
#        ,('D♯5',55,[keynum2f(55),2*keynum2f(55),3*keynum2f(55),4*keynum2f(55)],[1.0, 0.16478436132255364, 0.07783246648345495,0,0,0,0,0])
#        ,('E5',56,[keynum2f(56),2*keynum2f(56),3*keynum2f(56),4*keynum2f(56)],[1.0, 0.1415220970479249, 0.07254364786956904,0,0,0,0,0])
#        ,('F5',57,[keynum2f(57),2*keynum2f(57),3*keynum2f(57),4*keynum2f(57)],[1.0, 0.14996311223277023, 0.07311448273380237,0,0,0,0,0])
#        ,('F♯5',58,[keynum2f(58),2*keynum2f(58),3*keynum2f(58),4*keynum2f(58)],[1.0, 0.2647329004246385, 0.09319039754435957, 0.07204432143357493,0,0,0,0,0])
#        ,('G5',59,[keynum2f(59),2*keynum2f(59),3*keynum2f(59),4*keynum2f(59)],[1.0, 0.29433810009788186, 0.08864249646880727,0,0,0,0,0])
#        ,('G♯5',60,[keynum2f(60),2*keynum2f(60),3*keynum2f(60),4*keynum2f(60)],[1.0, 0.27267518900203863, 0.08940468637895038,0,0,0,0,0])
#        ,('A5',61,[keynum2f(61),2*keynum2f(61),3*keynum2f(61),4*keynum2f(61)],[1.0, 0.23907791376840112, 0.0804024395758299,0,0,0,0,0])
#        ,('A♯5',62,[keynum2f(62),2*keynum2f(62),3*keynum2f(62),4*keynum2f(62)],[1.0, 0.23589480613242153, 0.07438508306321302,0,0,0,0,0])
#        ,('B5',63,[keynum2f(63),2*keynum2f(63),3*keynum2f(63),4*keynum2f(63)],[1.0, 0.220599369203695, 0.0733036256894235,0,0,0,0,0])]

notes = [('C3',28,[keynum2f(28),2*keynum2f(28),3*keynum2f(28),4*keynum2f(28)],[1.0,1.8748572028842412,0.3964491587480385,0.31215121741146373,0.16284341749618064,0.22523097807724257,0.14773314715517125,0.16390082081613377])
       ,('C♯3',29,[keynum2f(29),2*keynum2f(29),3*keynum2f(29),4*keynum2f(29)],[1.0,1.641808167534372,0.362229104528428,0.3204856674017677,0.16009242547233515,0.21757203373160927,0.13014724989986423,0.1565141228439226])
       ,('D3',30,[keynum2f(30),2*keynum2f(30),3*keynum2f(30),4*keynum2f(30)],[1.0,1.7624720432557146,0.38973935602968285,0.28663995734911973,0.1550463223252811,0.2094878675597662,0.1297044423409354,0.15633189557469926])
       ,('D♯3',31,[keynum2f(31),2*keynum2f(31),3*keynum2f(31),4*keynum2f(31)],[1.0,0.684619288476615,0.05403268583420848,0.08247564203707748,0.09457374085631606,0.0684370921296874,0,0,0])
       ,('E3',32,[keynum2f(32),2*keynum2f(32),3*keynum2f(32),4*keynum2f(32)],[1.0,0.644814919294843,0.0524292356278788,0.07378480741465424,0.09784674514032232,0.06818101225973808,0,0,0])
       ,('F3',33,[keynum2f(33),2*keynum2f(33),3*keynum2f(33),4*keynum2f(33)],[1.0,0.6328411721378986,0.05272853181106699,0.07717785663706685,0.09266312228793924,0.067781748609678620,0,0])
       ,('F♯3',34,[keynum2f(34),2*keynum2f(34),3*keynum2f(34),4*keynum2f(34)],[1.0,0.5581524414391876,0.044202567804296614,0.06312671806084452,0.08133730635315288,0.061706490568839340,0,0,0])
       ,('G3',35,[keynum2f(35),2*keynum2f(35),3*keynum2f(35),4*keynum2f(35)],[1.0,0.5523796150087944,0.043284481581312206,0.06390858364936557,0.07939301094141947,0.05789010146996690,0,0,0])
       ,('G♯3',36,[keynum2f(36),2*keynum2f(36),3*keynum2f(36),4*keynum2f(36)],[1.0,0.5942229569448632,0.04427436213918945,0.06654105453842608,0.07846406467501106,0.062889432614303560,0,0,0])
       ,('A3',37,[keynum2f(37),2*keynum2f(37),3*keynum2f(37),4*keynum2f(37)],[1.0,0.7619580899495176,0.1045919068486756,0.13074141971372832,0.08461079636425631,0,0,0,0])
       ,('A♯3',38,[keynum2f(38),2*keynum2f(38),3*keynum2f(38),4*keynum2f(38)],[1.0,0.8501318147396106,0.10653965806673261,0.14385563250865366,0.08478375144555607,0,0,0,0])
       ,('B3',39,[keynum2f(39),2*keynum2f(39),3*keynum2f(39),4*keynum2f(39)],[1.0,0.8109901177231958,0.10439389881723116,0.13559165346145305,0.07923381544447580,0,0,0,0])
       ,('C4',40,[keynum2f(40),2*keynum2f(40),3*keynum2f(40),4*keynum2f(40)],[1,0.45072320093010165, 0.07756067699435863, 0.06233478319526727,0,0,0,0])
       ,('C♯4',41,[keynum2f(41),2*keynum2f(41),3*keynum2f(41),4*keynum2f(41)],[1,0.47975863251001355, 0.07705596758368384, 0.0590865572593957,0,0,0,0])
       ,('D4',42,[keynum2f(42),2*keynum2f(42),3*keynum2f(42),4*keynum2f(42)],[1,0.4435033621543764, 0.07408747655496659, 0.05481959721494538,0,0,0,0])
       ,('D♯4',43,[keynum2f(43),2*keynum2f(43),3*keynum2f(43),4*keynum2f(43)],[1,0.5572765658232384, 0.2805392604867455, 0.12346425135488595,0.11847019032008464,0,0,0,0])
       ,('E4',44,[keynum2f(44),2*keynum2f(44),3*keynum2f(44),4*keynum2f(44)],[1,0.560838969957909, 0.2627388110929595, 0.1230569628956918,0.11195465659120205,0,0,0,0,0])
       ,('F4',45,[keynum2f(45),2*keynum2f(45),3*keynum2f(45),4*keynum2f(45)],[1,0.5574742648780671,0.22399899087695116,0.11164689132907675,0.10444958701925663,0,0,0,0,0])
       ,('F♯4',46,[keynum2f(46),2*keynum2f(46),3*keynum2f(46),4*keynum2f(46)],[1,0.5574742648780671,0.22399899087695116,0.11164689132907675,0.10444958701925663,0,0,0,0,0])
       ,('G4',47,[keynum2f(47),2*keynum2f(47),3*keynum2f(47),4*keynum2f(47)],[1,0.07939819588721454, 0.03976683156570169,0,0,0,0,0])
       ,('G♯4',48,[keynum2f(48),2*keynum2f(48),3*keynum2f(48),4*keynum2f(48)],[1,0.08156058683677495, 0.03336236688670703,0,0,0,0,0])
       ,('A4',49,[keynum2f(49),2*keynum2f(49),3*keynum2f(49),4*keynum2f(49)],[1,0.07581809932930238, 0.03841706442666898,0,0,0,0,0])
       ,('A♯4',50,[keynum2f(50),2*keynum2f(50),3*keynum2f(50),4*keynum2f(50)],[1,0.07529571131165992, 0.041580966713429625,0,0,0,0,0])
       ,('B4',51,[keynum2f(51),2*keynum2f(51),3*keynum2f(51),4*keynum2f(51)],[1,0.08630751163794428, 0.039730627711715524,0,0,0,0,0])
       ,('C5',52,[keynum2f(52),2*keynum2f(52),3*keynum2f(52),4*keynum2f(52)],[1.0, 0.251182570561093, 0.16467943558284057,0,0,0,0,0])
       ,('C♯5',53,[keynum2f(53),2*keynum2f(53),3*keynum2f(53),4*keynum2f(53)],[1.0, 0.23748429609077507, 0.14979146857628187,0,0,0,0,0])
       ,('D5',54,[keynum2f(54),2*keynum2f(54),3*keynum2f(54),4*keynum2f(54)],[1.0, 0.2473262521596234, 0.17682499106142524,0,0,0,0,0])
       ,('D♯5',55,[keynum2f(55),2*keynum2f(55),3*keynum2f(55),4*keynum2f(55)],[1.0, 0.16478436132255364, 0.07783246648345495,0,0,0,0,0])
       ,('E5',56,[keynum2f(56),2*keynum2f(56),3*keynum2f(56),4*keynum2f(56)],[1.0, 0.1415220970479249, 0.07254364786956904,0,0,0,0,0])
       ,('F5',57,[keynum2f(57),2*keynum2f(57),3*keynum2f(57),4*keynum2f(57)],[1.0, 0.14996311223277023, 0.07311448273380237,0,0,0,0,0])
       ,('F♯5',58,[keynum2f(58),2*keynum2f(58),3*keynum2f(58),4*keynum2f(58)],[1.0, 0.2647329004246385, 0.09319039754435957, 0.07204432143357493,0,0,0,0,0])
       ,('G5',59,[keynum2f(59),2*keynum2f(59),3*keynum2f(59),4*keynum2f(59)],[1.0, 0.29433810009788186, 0.08864249646880727,0,0,0,0,0])
       ,('G♯5',60,[keynum2f(60),2*keynum2f(60),3*keynum2f(60),4*keynum2f(60)],[1.0, 0.27267518900203863, 0.08940468637895038,0,0,0,0,0])
       ,('A5',61,[keynum2f(61),2*keynum2f(61),3*keynum2f(61),4*keynum2f(61)],[1.0, 0.23907791376840112, 0.0804024395758299,0,0,0,0,0])
       ,('A♯5',62,[keynum2f(62),2*keynum2f(62),3*keynum2f(62),4*keynum2f(62)],[1.0, 0.23589480613242153, 0.07438508306321302,0,0,0,0,0])
       ,('B5',63,[keynum2f(63),2*keynum2f(63),3*keynum2f(63),4*keynum2f(63)],[1.0, 0.220599369203695, 0.0733036256894235,0,0,0,0,0])]


notes_f = []
for i in notes:
    notes_f+=i[2]
mer=merge(notes_f)   
new_notes=list(range(len(notes)))
for i in range(len(notes)):
    new_notes[i]=list(notes[i])
    del new_notes[i][2]
    new_notes[i].insert(2,[mer[4*i],mer[4*i+1],mer[4*i+2],mer[4*i+3]])

# print(new_notes)

# %%
data, fs = sf.read('G4.wav')
l=len(data)
lt=l/fs
t=np.linspace(0,lt,l)
plt.figure(figsize=(15,5))
plt.plot(t, data)

plt.show()

# %%
dataF=scipy.fft.fft(data)
dataF=abs(dataF[:round(20000)])

f=scipy.fft.fftfreq(l,1/fs)
f=f[:round(20000)]

plt.figure(figsize=(15,5))

plt.plot(f[0:],dataF[0:])

_,a=scipy.signal.find_peaks(dataF,height=0)
peaks,A=scipy.signal.find_peaks(dataF,distance=5*l/fs , height=0.4*max(a['peak_heights']) )

plt.plot(peaks[:]/l *fs, dataF[peaks], "x")

plt.show()

# %%
harmonics_frequency=peaks/l *fs  
harmonics_height=A['peak_heights']
L=list(zip(harmonics_frequency,harmonics_height))
for i in range(len(L)):
    L[i]=list(L[i])
# L

# %%
harmonics_frequency=peaks/l *fs  
harmonics_frequency=app(mer,harmonics_frequency)
harmonics_height=A['peak_heights']


L=list(zip(harmonics_frequency,harmonics_height))
for i in range(len(L)):
    L[i]=list(L[i])
# L

# %%
for i in range(len(L)) :
    for j in range(len(L)):
        if i<len(L) and j<len(L):
            if i!=j and L[i][0]==L[j][0]:
                L.insert(i,[L[i][0],L[i][1]+L[j][1]])
                L.remove(L[1+i])
                L.remove(L[j])
# L

# %%
# a=[]
# k=0
# for i in harmonics_height:
#     a+=[i/harmonics_height[0]]
#     k+=1
# a
#give_notes(L)
new_notes
# Out:
# [['C3',
#   28,
#   [132, 260, 392, 524],
#   [1.0,
#    1.8748572028842412,
#    0.3964491587480385,
#    0.31215121741146373,
#    0.16284341749618064,
#    0.22523097807724257,
#    0.14773314715517125,
#    0.16390082081613377]],
#  ['C♯3',
#   29,
#   [140, 276, 416, 556],
#   [1.0,
#    1.641808167534372,
#    0.362229104528428,
#    0.3204856674017677,
#    0.16009242547233515,
#    0.21757203373160927,
#    0.13014724989986423,
#    0.1565141228439226]],
#  ['D3',
#   30,
#   [148, 292, 440, 588],
#   [1.0,
#    1.7624720432557146,
#    0.38973935602968285,
#    0.28663995734911973,
#    0.1550463223252811,
#    0.2094878675597662,
#    0.1297044423409354,
#    0.15633189557469926]],
#  ['D♯3',
#   31,
#   [156, 312, 468, 624],
#   [1.0,
#    0.684619288476615,
#    0.05403268583420848,
#    0.08247564203707748,
#    0.09457374085631606,
#    0.0684370921296874,
#    0,
#    0,
#    0]],
#  ['E3',
#   32,
#   [164, 328, 496, 660],
#   [1.0,
#    0.644814919294843,
# ...

# %%
DATA,FS = sf.read('godfather.wav')
L=len(DATA)
# print(L)
LT=L/FS
print(LT)
ts = 0.4
n=int(LT/ts)
LT=n*ts
L=int(LT*FS)
ls=int(L/n)
print(n)
print(LT)
# Out:
# 38.37018140589569
# 95
# 38.0

# %%
def fullfft(DATA,FS):
    global ls
    global n
    
    f = scipy.fft.fftfreq(ls,1/FS)
    f = f[:round(4000)]
    freqs = []
    time = []
    dat = []
    for t in range(n):
            start=t*ls
            end=(t+1)*ls
            DATAF=scipy.fft.fft(DATA[start:end])
            DATAF=abs(DATAF[:round(4000)])
            freqs.append(f)
            time.append(t*ts)
            dat.append(DATAF)
    P=list(zip(time,freqs,dat))
    for i in range(len(time)):
        P[i]=list(P[i])
    
    return time,freqs,dat,P

def avv_max(L):
    s=[]
    for i in range(len(L)):
        s.append(max(L[i][2]))
    
    return max(s)*0.3

T,F,DATAF,P = fullfft(DATA, FS)
maxx=avv_max(P)

# def give_notes(G):
#     VV=deepcopy(G)
#     global maxx
#     global new_notes
#     S=[]
#     for j in range(len(VV)):
#         if VV[j][1]> 30 :
#             for i in range(len(new_notes)):
#                 if abs(VV[j][0] - new_notes[i][2][0]) < 4 :
#                     fundamental_height=VV[j][1]
#                     S.append(new_notes[i][0])
#                     VV[j][1]-=fundamental_height*new_notes[i][3][0]
#                     if type(find_ind(VV,app(mer,[2*VV[j][0]])))==int and new_notes[i][3][1]==float :
#                         VV[find_ind(VV,app(mer,[2*VV[j][0]])[0])][1]-=fundamental_height*new_notes[i][3][1]
#                         if type(find_ind(VV,app(mer,[3*VV[j][0]])))==int and new_notes[i][3][2]==float:
#                             VV[find_ind(VV,app(mer,[3*VV[j][0]])[0])][1]-=fundamental_height*new_notes[i][3][2]
#                         if type(find_ind(VV,app(mer,[4*VV[j][0]])))==int and new_notes[i][3][3]==float:
#                             VV[find_ind(VV,app(mer,[4*VV[j][0]])[0])][1]-=fundamental_height*new_notes[i][3][3] 
#                         if type(find_ind(VV,app(mer,[5*VV[j][0]])))==int and new_notes[i][3][4]==float:
#                             VV[find_ind(VV,app(mer,[5*VV[j][0]])[0])][1]-=fundamental_height*new_notes[i][3][4] 
#                         if type(find_ind(VV,app(mer,[6*VV[j][0]])))==int and new_notes[i][3][5]==float:
#                             VV[find_ind(VV,app(mer,[6*VV[j][0]])[0])][1]-=fundamental_height*new_notes[i][3][5] 
#                         if type(find_ind(VV,app(mer,[7*VV[j][0]])))==int and new_notes[i][3][6]==float:
#                             VV[find_ind(VV,app(mer,[7*VV[j][0]])[0])][1]-=fundamental_height*new_notes[i][3][6] 
#                     break 
        

#     return S  


def give_notes(G):
    VV=deepcopy(G)
    global maxx
    global new_notes
    S=[]
    for j in range(len(VV)):
        if VV[j][1]> 80 :
            for i in range(len(new_notes)):
                if abs(VV[j][0] - new_notes[i][2][0]) < 5 :
                    fundamental_height=VV[j][1]
                    S.append(new_notes[i][0])
                    VV[j][1]=0 
                    
                    if type(find_ind(VV,new_notes[i][2][1]))==int  :
                        if VV[find_ind(VV,new_notes[i][2][1])][1]<2*fundamental_height:
                            VV[find_ind(VV,new_notes[i][2][1])][1]=0

                            
                    if type(find_ind(VV,new_notes[i][2][2]))==int  :
                        if VV[find_ind(VV,new_notes[i][2][2])][1]<fundamental_height:
                            VV[find_ind(VV,new_notes[i][2][2])][1]=0
                          
                            
#                     if type(find_ind(VV,new_notes[i][2][2]))==int :
#                         if VV[find_ind(VV,new_notes[i][2][2])][1]<fundamental_height:
#                             VV[find_ind(VV,new_notes[i][2][2])][1]=0
#                             if type(find_ind(VV,new_notes[i][2][3]))==int :
#                                 VV[find_ind(VV,new_notes[i][2][3])][1]-=fundamental_height*new_notes[i][3][3] 
    #                         if type(find_ind(VV,new_notes[i][2][4]))==int :
    #                             VV[find_ind(VV,new_notes[i][2][4])][1]-=fundamental_height*new_notes[i][3][4] 
    #                         if type(find_ind(VV,new_notes[i][2][5]))==int :
    #                             VV[find_ind(VV,new_notes[i][2][5])][1]-=fundamental_height*new_notes[i][3][5] 
    #                         if type(find_ind(VV,new_notes[i][2][6]))==int :
    #                             VV[find_ind(VV,new_notes[i][2][6])][1]-=fundamental_height*new_notes[i][3][6] 
                    break 
        

    return S 
  
    
def f2key(a):
    global new_notes
    k=0
    for i in range(len(new_notes)):
        if new_notes[i][2][0]==a:
            k=1
            return new_notes[i][0]
            break
    if k==0:
        return 0
    
def key2f(a):
    global new_notes
    k=0
    for i in range(len(new_notes)):
        if new_notes[i][0]==a:
            k=1
            return new_notes[i][2][0]
            break
    if k==0:
        return 0
        
i = 0

# %%
T,F,DATAF,P = fullfft(DATA, FS)
q=2
maxx=avv_max(P)

plt.figure(figsize=(15,5))
plt.plot(F[q][:],DATAF[q][:])
# _,a=scipy.signal.find_peaks(DATAF[q],height=0)
# peaks,A=scipy.signal.find_peaks(DATAF[q],distance=3*l/fs , height=1/3*max(a['peak_heights']) )
peaks,A=scipy.signal.find_peaks(DATAF[q],distance=5*ls/FS , height=80 )

plt.plot(peaks[:]/ls *FS, DATAF[q][peaks], "x")
plt.show() 
peaks/ls *FS
# Out:
# array([], dtype=float64)

# %%
PEAKS_frequency=[]
PEAKS_height=[]
L=[]


for o in range(len(P)):
    
#     _, b = scipy.signal.find_peaks(DATAF[o], distance = 5*ls/FS, height = 0)
#     peak_info,B=scipy.signal.find_peaks(DATAF[o],distance=5 , height=0.3*max(b['peak_heights']) )

    peak_info, B = scipy.signal.find_peaks(DATAF[o], distance = 5*ls/FS, height = 80)

#     peak_info,B=scipy.signal.find_peaks(DATAF[o],distance=5*ls/FS , height=maxx )
    
    harmonic_frequency_one=peak_info/ls *FS  
    harmonic_frequency_one=app(mer,harmonic_frequency_one)
    harmonic_height_one=B['peak_heights']
    PEAKS_height.append(harmonic_height_one)
    PEAKS_frequency.append(harmonic_frequency_one)
    harmonic_info = list(zip(harmonic_frequency_one,harmonic_height_one))
    for i in range(len(harmonic_info)):
        harmonic_info[i]=list(harmonic_info[i])
    
    for i in range(len(harmonic_info)) :
        for j in range(len(harmonic_info)):
            if i < len(harmonic_info) and j < len(harmonic_info):
                if i!=j and harmonic_info[i][0]==harmonic_info[j][0]:
                    harmonic_info.insert(i,[harmonic_info[i][0],harmonic_info[i][1]+harmonic_info[j][1]])
                    harmonic_info.remove(harmonic_info[1+i])
                    harmonic_info.remove(harmonic_info[j])
                    
    L.append(harmonic_info)
            
list(zip(T,L))
for m in range(n):
    print(T[m])
    print(give_notes(L[m]))
    print(L[m])
# Out:
# 0.0
# []
# []
# 0.4
# []
# []
# 0.8
# []
# []
# 1.2000000000000002
# ['F♯3']
# [[184.0, 374.7112964580506], [368.0, 289.56317066668186]]
# 1.6
# ['F♯3', 'B3']
# [[184.0, 236.07682630545304], [248.0, 258.2504045143389], [368.0, 121.18016213662013], [492.0, 138.73241708833004]]
# 2.0
# ['B3']
# [[248.0, 197.0765289060013], [492.0, 164.6075758074725]]
# 2.4000000000000004
# ['D4']
# [[292.0, 345.1359640704234], [588.0, 210.9159872712133]]
# 2.8000000000000003
# ['C♯4', 'D4']
# [[276.0, 223.93677456085834], [292.0, 258.44884074160007], [556.0, 108.92884255260316], [588.0, 124.21626227810293]]
# 3.2
# ['C♯4']
# [[276.0, 381.13168654201604], [556.0, 133.49949901692236]]
# 3.6
# ['B3', 'C♯4']
# [[248.0, 309.8718580321157], [276.0, 90.68989201333058], [492.0, 200.22853334992746]]
# 4.0
# ['B3', 'D4']
# [[248.0, 130.71346976708077], [292.0, 264.90992350170825], [492.0, 112.05293054290485], [588.0, 142.05817304934735]]
# 4.4
# ['B3', 'D4']
# ...

# %%
#  for m in range(n):
#      print(give_notes(L[m]))
#      print(L[m])


def check_height(name, LL):
    keynum = 0
    for i in new_notes:
        if i[0] == name:
            f = i[2][0]
   
    for j in LL:
        if j[0] == f:
            return j[1]
    return 0
        
# print(keynum2f(40))

played = [['C3', 0], ['C♯3', 0], ['D3', 0], ['D♯3', 0], ['E3', 0], ['F3', 0], ['F♯3', 0], ['G3', 0], ['G♯3', 0], ['A3', 0], ['A♯3', 0], ['B3', 0],
       ['C4', 0], ['C♯4', 0], ['D4', 0], ['D♯4', 0], ['E4', 0], ['F4', 0], ['F♯4', 0], ['G4', 0], ['G♯4', 0], ['A4', 0], ['A♯4', 0], ['B4', 0],
       ['C5', 0], ['C♯5', 0], ['D5', 0], ['D♯5', 0], ['E5', 0], ['F5', 0], ['F♯5', 0], ['G5', 0], ['G♯5', 0], ['A5', 0], ['A♯5', 0], ['B5', 0]]


time = []
for i in range(n):
    time += [[round(i*ts, 2),round((i + 1)*ts, 2)]]
for i in range(n):
    if i != 0 and i != n - 1:
        notess = give_notes(L[i])
        for j in notess:
            #if (check_height(j, L[i - 1])) > 0 or (check_height(j, L[i + 1])) > 0:
            time[i] += [j]
            if (check_height(j, L[i])) > (check_height(j, L[i - 1])):
                 for k in played:
                        
                        if k[0] == j and k[1] == 0:
                            
                            time[i] += ['new']
                            k[1] = 1
                            break
#             elif (check_height(j, L[i])) < (check_height(j, L[i - 1])):
#                 for k in played:
#                     if k[0] == j:
#                         k[1] = 0        
        
for i in time:
    print(i)
    print('\n')
# Out:
# [0.0, 0.4]
#
#
# [0.4, 0.8]
#
#
# [0.8, 1.2]
#
#
# [1.2, 1.6, 'F♯3', 'new']
#
#
# [1.6, 2.0, 'F♯3', 'B3', 'new']
#
#
# [2.0, 2.4, 'B3']
#
#
# [2.4, 2.8, 'D4', 'new']
#
#
# [2.8, 3.2, 'C♯4', 'new', 'D4']
#
#
# [3.2, 3.6, 'C♯4']
#
#
# [3.6, 4.0, 'B3', 'C♯4']
#
#
# [4.0, 4.4, 'B3', 'D4']
#
#
# [4.4, 4.8, 'B3', 'D4']
#
#
# [4.8, 5.2, 'B3']
#
#
# [5.2, 5.6, 'B3', 'C♯4']
#
#
# [5.6, 6.0, 'B3', 'C♯4']
#
#
# [6.0, 6.4, 'B3']
#
#
# [6.4, 6.8, 'G3', 'new', 'B3']
#
#
# [6.8, 7.2, 'G3', 'A3', 'new']
#
#
# [7.2, 7.6, 'A3']
#
#
# [7.6, 8.0, 'F♯3']
#
#
# [8.0, 8.4, 'F♯3']
#
#
# [8.4, 8.8, 'F♯3']
#
#
# [8.8, 9.2, 'F♯3']
#
#
# [9.2, 9.6, 'F♯3']
#
#
# [9.6, 10.0, 'F♯3', 'B3']
#
#
# [10.0, 10.4, 'B3', 'D4']
#
#
# [10.4, 10.8, 'D4']
#
#
# [10.8, 11.2, 'C♯4', 'D4']
#
#
# [11.2, 11.6, 'B3', 'C♯4']
#
#
# [11.6, 12.0, 'B3']
#
#
# [12.0, 12.4, 'D4']
#
#
# [12.4, 12.8, 'A♯3', 'new', 'B3', 'D4']
#
#
# [12.8, 13.2, 'B3']
#
#
# [13.2, 13.6, 'C♯4', 'B4']
#
#
# [13.6, 14.0, 'B3', 'C♯4']
#
#
# ...

# %%
fig = plt.figure(dpi=40)
ax = fig.add_subplot(1,1,1)

# tdata = [
#     ["matched gt", 10],
#     ["unmatched gt", 20],
#     ["total gt", 30],
#     ["mean_precision", 0.6],
#     ["mean_recall", 0.4]
# ]

tdata = []
col = []
for i in range(37):
    tdata.append([])
    col.append([])
    for j in range(n + 1):
        col[i].append('1')
        tdata[i].append('')
   
for i in range(36):
    tdata[-i - 1][0] = notes[i][0]
    for j in range(n):
        if notes[i][0] in time[j]:
            col[-i - 1][j + 1] = '0.5'
            if time[j].index(notes[i][0]) + 1 < len(time[j]):
                if time[j][time[j].index(notes[i][0]) + 1] == 'new':
                    col[-i - 1][j + 1] = '0.1'
        else:
            col[-i - 1][0] = '0.8'
            
            
    
    
for i in range(n):
    tdata[0][i + 1] = "{0:.1f}".format(i*ts)
    col[0][i + 1] = '0.8'


table = ax.table(cellText = tdata, cellColours = col, loc = 'center')
table.set_fontsize(15)
table.scale(10,2)
ax.axis('off')
plt.show()
